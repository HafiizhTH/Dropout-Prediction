# %% [markdown]
# # Submission Akhir: Menyelesaikan Permasalahan Institusi Pendidikan
#
# - Nama: Hafiizh Taufiqul Hakim
# - Email: 2012500720@student.budiluhur.ac.id
# - Id Dicoding: hafizhtaufiqul1002

# %% [markdown]
# # Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
dataset = "https://raw.githubusercontent.com/HafiizhTH/Dropout-Prediction/main/Data/Data_to_Visualisasi.csv"

# %%
df = pd.read_csv(dataset)
df.head().T
# Out:
#                                                                                               0  \
# Marital_status                                                                    Belum Menikah
# Application_mode                                                 2nd phase - general contingent
# Application_order                                                                             5
# Course                                                          Animation and Multimedia Design
# Daytime_evening_attendance                                                              Daytime
# Previous_qualification                                                      Secondary education
# Previous_qualification_grade                                                                122
# Nacionality                                                                          Portuguese
# Mothers_qualification                         Basic Education 3rd Cycle (9th/10th/11th Year)...
# Fathers_qualification                                            Other - 11th Year of Schooling
# Mothers_occupation                                                             Layanan dan Jasa
# Fathers_occupation                                                          Belum/Tidak Bekerja
# Admission_grade                                                                             127
# Displaced                                                                                   Iya
# Educational_special_needs                                                                 Tidak
# Debtor                                                                                    Tidak
# Tuition_fees_up_to_date                                                                     Iya
# Gender                                                                                Laki-laki
# Scholarship_holder                                                                        Tidak
# Age_at_enrollment                                                                            20
# International                                                                             Tidak
# Curricular_units_1st_sem_credited                                                             0
# Curricular_units_1st_sem_enrolled                                                             0
# Curricular_units_1st_sem_evaluations                                                          0
# Curricular_units_1st_sem_approved                                                             0
# Curricular_units_1st_sem_grade                                                                0
# Curricular_units_1st_sem_without_evaluations                                                  0
# Curricular_units_2nd_sem_credited                                                             0
# Curricular_units_2nd_sem_enrolled                                                             0
# Curricular_units_2nd_sem_evaluations                                                          0
# Curricular_units_2nd_sem_approved                                                             0
# Curricular_units_2nd_sem_grade                                                                0
# Curricular_units_2nd_sem_without_evaluations                                                  0
# Unemployment_rate                                                                            10
# Inflation_rate                                                                                1
# GDP                                                                                           1
# Status                                                                                  Dropout
#
#                                                                                               1  \
# Marital_status                                                                    Belum Menikah
# Application_mode                                               International student (bachelor)
# Application_order                                                                             1
# Course                                                                                  Tourism
# Daytime_evening_attendance                                                              Daytime
# Previous_qualification                                                      Secondary education
# Previous_qualification_grade                                                                160
# Nacionality                                                                          Portuguese
# Mothers_qualification                         Secondary Education - 12th Year of Schooling o...
# Fathers_qualification                                                 Higher Education - Degree
# Mothers_occupation                                                         Spesialis IT/Teknisi
# Fathers_occupation                                                         Spesialis IT/Teknisi
# Admission_grade                                                                             142
# Displaced                                                                                   Iya
# Educational_special_needs                                                                 Tidak
# Debtor                                                                                    Tidak
# Tuition_fees_up_to_date                                                                   Tidak
# Gender                                                                                Laki-laki
# Scholarship_holder                                                                        Tidak
# Age_at_enrollment                                                                            19
# International                                                                             Tidak
# Curricular_units_1st_sem_credited                                                             0
# Curricular_units_1st_sem_enrolled                                                             6
# Curricular_units_1st_sem_evaluations                                                          6
# Curricular_units_1st_sem_approved                                                             6
# Curricular_units_1st_sem_grade                                                               14
# Curricular_units_1st_sem_without_evaluations                                                  0
# Curricular_units_2nd_sem_credited                                                             0
# Curricular_units_2nd_sem_enrolled                                                             6
# Curricular_units_2nd_sem_evaluations                                                          6
# Curricular_units_2nd_sem_approved                                                             6
# Curricular_units_2nd_sem_grade                                                               13
# Curricular_units_2nd_sem_without_evaluations                                                  0
# Unemployment_rate                                                                            13
# Inflation_rate                                                                                0
# GDP                                                                                           0
# Status                                                                                 Graduate
#
#                                                                                               2  \
# Marital_status                                                                    Belum Menikah
# Application_mode                                                 1st phase - general contingent
# Application_order                                                                             5
# Course                                                                     Communication Design
# Daytime_evening_attendance                                                              Daytime
# Previous_qualification                                                      Secondary education
# Previous_qualification_grade                                                                122
# Nacionality                                                                          Portuguese
# Mothers_qualification                         Basic Education 1st Cycle (4th/5th Year) or Eq...
# Fathers_qualification                         Basic Education 1st Cycle (4th/5th Year) or Eq...
# Mothers_occupation                                                          Belum/Tidak Bekerja
# Fathers_occupation                                                          Belum/Tidak Bekerja
# Admission_grade                                                                             124
# Displaced                                                                                   Iya
# Educational_special_needs                                                                 Tidak
# Debtor                                                                                    Tidak
# Tuition_fees_up_to_date                                                                   Tidak
# Gender                                                                                Laki-laki
# Scholarship_holder                                                                        Tidak
# Age_at_enrollment                                                                            19
# International                                                                             Tidak
# Curricular_units_1st_sem_credited                                                             0
# Curricular_units_1st_sem_enrolled                                                             6
# Curricular_units_1st_sem_evaluations                                                          0
# Curricular_units_1st_sem_approved                                                             0
# Curricular_units_1st_sem_grade                                                                0
# Curricular_units_1st_sem_without_evaluations                                                  0
# Curricular_units_2nd_sem_credited                                                             0
# Curricular_units_2nd_sem_enrolled                                                             6
# Curricular_units_2nd_sem_evaluations                                                          0
# Curricular_units_2nd_sem_approved                                                             0
# Curricular_units_2nd_sem_grade                                                                0
# Curricular_units_2nd_sem_without_evaluations                                                  0
# Unemployment_rate                                                                            10
# Inflation_rate                                                                                1
# GDP                                                                                           1
# Status                                                                                  Dropout
#
#                                                                                               3  \
# Marital_status                                                                    Belum Menikah
# Application_mode                                                 2nd phase - general contingent
# Application_order                                                                             2
# Course                                                             Journalism and Communication
# Daytime_evening_attendance                                                              Daytime
# Previous_qualification                                                      Secondary education
# Previous_qualification_grade                                                                122
# Nacionality                                                                          Portuguese
# Mothers_qualification                         Basic Education 2nd Cycle (6th/7th/8th Year) o...
# Fathers_qualification                         Basic Education 1st Cycle (4th/5th Year) or Eq...
# Mothers_occupation                                                             Layanan dan Jasa
# Fathers_occupation                                                         Spesialis IT/Teknisi
# Admission_grade                                                                             119
# Displaced                                                                                   Iya
# Educational_special_needs                                                                 Tidak
# Debtor                                                                                    Tidak
# Tuition_fees_up_to_date                                                                     Iya
# Gender                                                                                Perempuan
# Scholarship_holder                                                                        Tidak
# Age_at_enrollment                                                                            20
# International                                                                             Tidak
# Curricular_units_1st_sem_credited                                                             0
# Curricular_units_1st_sem_enrolled                                                             6
# Curricular_units_1st_sem_evaluations                                                          8
# Curricular_units_1st_sem_approved                                                             6
# Curricular_units_1st_sem_grade                                                               13
# Curricular_units_1st_sem_without_evaluations                                                  0
# Curricular_units_2nd_sem_credited                                                             0
# Curricular_units_2nd_sem_enrolled                                                             6
# Curricular_units_2nd_sem_evaluations                                                         10
# Curricular_units_2nd_sem_approved                                                             5
# Curricular_units_2nd_sem_grade                                                               12
# Curricular_units_2nd_sem_without_evaluations                                                  0
# Unemployment_rate                                                                             9
# Inflation_rate                                                                                0
# GDP                                                                                          -3
# Status                                                                                 Graduate
#
#                                                                                               4
# Marital_status                                                                    Sudah Menikah
# Application_mode                                                              Over 23 years old
# Application_order                                                                             1
# Course                                                      Social Service (evening attendance)
# Daytime_evening_attendance                                                              Evening
# Previous_qualification                                                      Secondary education
# Previous_qualification_grade                                                                100
# Nacionality                                                                          Portuguese
# Mothers_qualification                         Basic Education 1st Cycle (4th/5th Year) or Eq...
# Fathers_qualification                         Basic Education 2nd Cycle (6th/7th/8th Year) o...
# Mothers_occupation                                                          Belum/Tidak Bekerja
# Fathers_occupation                                                          Belum/Tidak Bekerja
# Admission_grade                                                                             141
# Displaced                                                                                 Tidak
# Educational_special_needs                                                                 Tidak
# Debtor                                                                                    Tidak
# Tuition_fees_up_to_date                                                                     Iya
# Gender                                                                                Perempuan
# Scholarship_holder                                                                        Tidak
# Age_at_enrollment                                                                            45
# International                                                                             Tidak
# Curricular_units_1st_sem_credited                                                             0
# Curricular_units_1st_sem_enrolled                                                             6
# Curricular_units_1st_sem_evaluations                                                          9
# Curricular_units_1st_sem_approved                                                             5
# Curricular_units_1st_sem_grade                                                               12
# Curricular_units_1st_sem_without_evaluations                                                  0
# Curricular_units_2nd_sem_credited                                                             0
# Curricular_units_2nd_sem_enrolled                                                             6
# Curricular_units_2nd_sem_evaluations                                                          6
# Curricular_units_2nd_sem_approved                                                             6
# Curricular_units_2nd_sem_grade                                                               13
# Curricular_units_2nd_sem_without_evaluations                                                  0
# Unemployment_rate                                                                            13
# Inflation_rate                                                                                0
# GDP                                                                                           0
# Status                                                                                 Graduate

# %% [markdown]
# # EDA

# %% [markdown]
# ### Statistik Deskriptif

# %%
num = df.select_dtypes(exclude='object').columns
cat = df.select_dtypes(include='object').columns

# %%
# Statistik deskriptif untuk data numerik
df[num].describe()
# Out:
#        Application_order  Previous_qualification_grade  Admission_grade  \
# count        3416.000000                   3416.000000      3416.000000
# mean            1.761710                    133.003220       127.054742
# std             1.337162                     13.276968        14.645391
# min             0.000000                     95.000000        95.000000
# 25%             1.000000                    125.000000       118.000000
# 50%             1.000000                    133.000000       126.000000
# 75%             2.000000                    140.000000       135.000000
# max             6.000000                    190.000000       190.000000
#
#        Age_at_enrollment  Curricular_units_1st_sem_credited  \
# count        3416.000000                        3416.000000
# mean           23.269321                           0.687939
# std             7.721625                           2.327589
# min            17.000000                           0.000000
# 25%            19.000000                           0.000000
# 50%            20.000000                           0.000000
# 75%            25.000000                           0.000000
# max            70.000000                          20.000000
#
#        Curricular_units_1st_sem_enrolled  \
# count                        3416.000000
# mean                            6.271077
# std                             2.455161
# min                             0.000000
# 25%                             6.000000
# 50%                             6.000000
# 75%                             7.000000
# max                            26.000000
#
#        Curricular_units_1st_sem_evaluations  \
# count                           3416.000000
# mean                               7.853337
# std                                4.044537
# min                                0.000000
# 25%                                6.000000
# 50%                                8.000000
# 75%                                9.000000
# max                               36.000000
#
#        Curricular_units_1st_sem_approved  Curricular_units_1st_sem_grade  \
# count                        3416.000000                     3416.000000
# mean                            4.789813                       10.208431
# std                             3.140772                        4.913173
# min                             0.000000                        0.000000
# 25%                             3.000000                       11.000000
# 50%                             6.000000                       12.000000
# 75%                             6.000000                       13.000000
# max                            26.000000                       18.000000
#
#        Curricular_units_1st_sem_without_evaluations  \
# count                                   3416.000000
# mean                                       0.054742
# std                                        0.326821
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        6.000000
#
#        Curricular_units_2nd_sem_credited  Curricular_units_2nd_sem_enrolled  \
# count                        3416.000000                        3416.000000
# mean                            0.520199                           6.248536
# std                             1.871932                           2.178424
# min                             0.000000                           0.000000
# 25%                             0.000000                           5.000000
# 50%                             0.000000                           6.000000
# 75%                             0.000000                           7.000000
# max                            19.000000                          19.000000
#
#        Curricular_units_2nd_sem_evaluations  \
# count                           3416.000000
# mean                               7.561183
# std                                3.812948
# min                                0.000000
# 25%                                6.000000
# 50%                                8.000000
# 75%                                9.000000
# max                               25.000000
#
#        Curricular_units_2nd_sem_approved  Curricular_units_2nd_sem_grade  \
# count                        3416.000000                     3416.000000
# mean                            4.531030                        9.748829
# std                             3.105029                        5.323736
# min                             0.000000                        0.000000
# 25%                             2.000000                       10.000000
# 50%                             5.000000                       12.000000
# 75%                             6.000000                       13.000000
# max                            19.000000                       18.000000
#
#        Curricular_units_2nd_sem_without_evaluations  Unemployment_rate  \
# count                                        3416.0        3416.000000
# mean                                            0.0          11.090164
# std                                             0.0           2.687983
# min                                             0.0           7.000000
# 25%                                             0.0           9.000000
# 50%                                             0.0          11.000000
# 75%                                             0.0          13.000000
# max                                             0.0          16.000000
#
#        Inflation_rate          GDP
# count     3416.000000  3416.000000
# mean         0.922717    -0.119145
# std          1.046726     1.978398
# min          0.000000    -4.000000
# 25%          0.000000    -1.000000
# 50%          1.000000     0.000000
# 75%          2.000000     1.000000
# max          3.000000     3.000000

# %%
# Statistik deskriptif untuk data kategorik
df[cat].describe()
# Out:
#        Marital_status                Application_mode   Course  \
# count            3416                            3416     3416
# unique              4                              18       16
# top     Belum Menikah  1st phase - general contingent  Nursing
# freq             3046                            1348      624
#
#        Daytime_evening_attendance Previous_qualification Nacionality  \
# count                        3416                   3416        3416
# unique                          2                     16          18
# top                       Daytime    Secondary education  Portuguese
# freq                         3039                   2862        3332
#
#                                     Mothers_qualification  \
# count                                                3416
# unique                                                 27
# top     Secondary Education - 12th Year of Schooling o...
# freq                                                  826
#
#                                     Fathers_qualification  \
# count                                                3412
# unique                                                 28
# top     Basic Education 1st Cycle (4th/5th Year) or Eq...
# freq                                                  944
#
#          Mothers_occupation   Fathers_occupation Displaced  \
# count                  3400                 3416      3416
# unique                   12                   12         2
# top     Belum/Tidak Bekerja  Belum/Tidak Bekerja       Iya
# freq                   1432                  989      1895
#
#        Educational_special_needs Debtor Tuition_fees_up_to_date     Gender  \
# count                       3416   3416                    3416       3416
# unique                         2      2                       2          2
# top                        Tidak  Tidak                     Iya  Perempuan
# freq                        3377   3039                    2981       2269
#
#        Scholarship_holder International    Status
# count                3416          3416      3416
# unique                  2             2         2
# top                 Tidak         Tidak  Graduate
# freq                 2474          3332      2118

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Fitur Numerik

# %%
# Mengidentifikasi untuk kolom numerik
num_plots = len(num)
num_rows = (num_plots // 3) + 1
num_cols = 3

# %%
# Kde
rcParams['figure.figsize'] = 18, 5 * num_rows
for i in range(0, len(num)):
    plt.subplot(num_rows, num_cols, i+1)
    sns.kdeplot(x=df[num[i]], palette='#4793AF')
    plt.title(num[i], fontsize=12, fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()

# %%
# Boxplot
rcParams['figure.figsize'] = 18, 5 * num_rows
for i in range(0, len(num)):
    plt.subplot(num_rows, num_cols, i+1)
    sns.boxplot(x=df[num[i]], color='#4793AF')
    plt.title(num[i], fontsize=12, fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ##### Fitur Kategorik

# %%
# Mengidentifikasi untuk kolom kategorik
cat_plots = len(cat)
cat_rows = (cat_plots // 1) + 1
cat_cols = 1

# %%
def generate_palette(series):
    max_val = series.value_counts().idxmax()
    min_val = series.value_counts().idxmin()
    colors = ['#DD5746' if val == min_val else '#FFC470' if val == max_val else '#4793AF' for val in series.unique()]
    return dict(zip(series.unique(), colors))

rcParams['figure.figsize'] = 18, 10 * cat_rows
for i in range(0, len(cat)):
    plt.subplot(cat_rows, cat_cols, i+1)
    palette = generate_palette(df[cat[i]])
    sns.countplot(y=df[cat[i]], palette=palette)
    plt.title(cat[i], fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ##### Hubungan dari setiap kolom

# %%
corr = df[num].corr()
plt.figure(figsize=(20, 16))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16, fontweight='bold')
plt.xticks(rotation=90, fontsize=16)
plt.yticks(rotation=0, fontsize=16)
plt.show()
